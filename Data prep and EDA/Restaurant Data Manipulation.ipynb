# %% [markdown]
# #### Importing the libs

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# #### Importing the relevant data sets

# %%
ratings = pd.read_csv("rating_final.csv")
users = pd.read_csv("userprofile.csv")
restaurants = pd.read_csv("geoplaces2.csv")

# %% [markdown]
# #### See the first 5 rows of each different data set

# %%
ratings.head()

# %%
users.head()

# %%
restaurants.head()

# %% [markdown]
# #### View basic information of each data set

# %% [raw]
# restaurants.info()
# restaurants.describe()

# %%
users.info()
users.describe()

# %%
ratings.info()
ratings.describe()

# %% [markdown]
# #### Merge the data sets in order to obtain a useful one

# %%
df = pd.merge(left=ratings, right=users, on="userID", how="left")
reviews_test=pd.merge(left=df, right=restaurants, on="placeID", how="left")

# %% [markdown]
# #### View the new reviews data set and prepare it

# %%
reviews_test.head()

# %% [markdown]
# #### Drop useless columns

# %%
reviews_test.columns

# %%
reviews_test.drop([ 'state', 'country', 'fax','hijos','accessibility',
            'weight','color','franchise','ambience' ,'personality','interest','religion',
             'weight' ,'height','the_geom_meter','zip','Rambience','url'],inplace=True,axis=1)

# %% [markdown]
# #### Create a new column for the ratings and drop the other ones

# %%
reviews_test['GlobalRatings']=reviews_test['food_rating']+reviews_test['service_rating']+reviews_test['rating']
reviews_test.drop(['food_rating','service_rating','rating'],inplace=True,axis=1)

# %% [markdown]
# #### Drop when the ratings is 0

# %%
reviews_test.drop(reviews_test[reviews_test.GlobalRatings==0].index , inplace=True)

# %% [markdown]
# #### Create Age column from the Birth_year column and drop it

# %%
reviews_test['age']=2019-reviews_test['birth_year']
reviews_test.drop('birth_year',inplace=True,axis=1)

# %% [markdown]
# #### Analyse The reviews data

# %%
reviews_test.head()

# %%
reviews_test.info()

# %%
reviews_test.describe()

# %% [markdown]
# #### Replace ? with Nan

# %%
reviews_test.replace('?', np.nan,inplace=True)

# %% [markdown]
# #### Plotting the missing values

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(reviews_test.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# #### The percentage of missing values in each column

# %%
percent_missing = reviews_test.isnull().sum() * 100 / len(reviews_test)
missing_value_df = pd.DataFrame({'column_name': reviews_test.columns,
                                 'percent_missing': percent_missing})
missing_value_df['percent_missing']>50
print(missing_value_df)

# %% [markdown]
# #### Drop the address column since it has a 15% of empty data

# %%
reviews_test.drop('address',inplace=True,axis=1)

# %% [markdown]
# #### Importing the geopy lib

# %%
from geopy.distance import geodesic

# %% [markdown]
# #### Create a small function to measure the distance between the clients and restaurants

# %%
def distancer(row):
    coords_1 = (row['latitude_x'], row['longitude_x'])
    coords_2 = (row['latitude_y'], row['longitude_y'])
    return geodesic(coords_1, coords_2).km

# %% [markdown]
# #### Create a new comumn for the measured distance in Km

# %%
reviews_test['distance'] = reviews_test.apply(distancer, axis=1)

# %% [markdown]
# #### View the data after modification

# %%
reviews_test.head()

# %% [markdown]
# #### Drop the irrelevant columns

# %%
reviews_test.drop(['latitude_y','longitude_y','city','latitude_x','longitude_x'],inplace=True,axis=1)

# %% [markdown]
# #### Create a colmun to classify the reviews

# %%
reviews_test.loc[(reviews_test['GlobalRatings'] ==6) | (reviews_test['GlobalRatings'] ==5), 'Review_State'] = 'Excellent'
reviews_test.loc[(reviews_test['GlobalRatings'] ==4) | (reviews_test['GlobalRatings'] ==3), 'Review_State'] = 'Medium'
reviews_test.loc[(reviews_test['GlobalRatings'] ==2) | (reviews_test['GlobalRatings'] ==1), 'Review_State'] = 'Bad'

# %% [markdown]
# #### Update the user Id as a numerical value

# %%
reviews_test['userID']=reviews_test['userID'].apply(lambda x:x.split('U')[1])

# %%
reviews=pd.read_csv('reviewsOrg.csv')

# %%
reviews.head(34)
# Out:
#     userID  placeID smoker     drink_level dress_preference  transport  \
# 0     1077   135085  False  social drinker          elegant     public
# 1     1077   135038  False  social drinker          elegant     public
# 2     1077   132825  False  social drinker          elegant     public
# 3     1077   135060  False  social drinker          elegant     public
# 4     1068   135104  False  casual drinker         informal     public
# 5     1068   132663  False  casual drinker         informal     public
# 6     1068   132630  False  casual drinker         informal     public
# 7     1067   132584  False      abstemious    no preference     public
# 8     1067   132733  False      abstemious    no preference     public
# 9     1067   132732  False      abstemious    no preference     public
# 10    1067   132630  False      abstemious    no preference     public
# 11    1067   132560  False      abstemious    no preference     public
# 12    1103   132584  False      abstemious           formal     public
# 13    1103   132732  False      abstemious           formal     public
# 14    1103   132630  False      abstemious           formal     public
# 15    1103   132613  False      abstemious           formal     public
# 16    1103   132667  False      abstemious           formal     public
# 17    1103   135104  False      abstemious           formal     public
# 18    1103   132663  False      abstemious           formal     public
# 19    1103   132733  False      abstemious           formal     public
# 20    1107   132660  False      abstemious    no preference  car owner
# 21    1107   132584  False      abstemious    no preference  car owner
# 22    1107   132733  False      abstemious    no preference  car owner
# 23    1044   135088   True  social drinker         informal  car owner
# 24    1044   132583   True  social drinker         informal  car owner
# 25    1070   132608  False  casual drinker         informal     public
# 26    1070   132609  False  casual drinker         informal     public
# 27    1070   132613  False  casual drinker         informal     public
# 28    1082   132630   True      abstemious         informal     public
# 29    1060   132564  False  casual drinker           formal     public
# 30    1060   132717  False  casual drinker           formal     public
# 31    1060   132733  False  casual drinker           formal     public
# 32    1060   132740  False  casual drinker           formal     public
# 33    1123   132733  False      abstemious         informal        NaN
#
#    marital_status      activity  budget  \
# 0         married       student  medium
# 1         married       student  medium
# 2         married       student  medium
# 3         married       student  medium
# 4          single       student     low
# 5          single       student     low
# 6          single       student     low
# 7          single       student  medium
# 8          single       student  medium
# 9          single       student  medium
# 10         single       student  medium
# 11         single       student  medium
# 12         single  professional  medium
# 13         single  professional  medium
# 14         single  professional  medium
# 15         single  professional  medium
# 16         single  professional  medium
# 17         single  professional  medium
# 18         single  professional  medium
# 19         single  professional  medium
# 20         single           NaN    high
# 21         single           NaN    high
# 22         single           NaN    high
# 23        married  professional  medium
# 24        married  professional  medium
# 25         single       student     low
# 26         single       student     low
# 27         single       student     low
# 28         single       student  medium
# 29         single       student  medium
# 30         single       student  medium
# 31         single       student  medium
# 32         single       student  medium
# 33         single       student  medium
#
#                                      name            alcohol   smoking_area  \
# 0                  Tortas Locas Hipocampo  No_Alcohol_Served  not permitted
# 1                   Restaurant la Chalita  No_Alcohol_Served        section
# 2                         puesto de tacos  No_Alcohol_Served           none
# 3                 Restaurante Marisco Sam  No_Alcohol_Served           none
# 4                                    vips           Full_Bar  not permitted
# 5                               tacos abi  No_Alcohol_Served           none
# 6                              palomo tec  No_Alcohol_Served           none
# 7                      Gorditas Dona Tota  No_Alcohol_Served  not permitted
# 8                           Little Cesarz  No_Alcohol_Served  not permitted
# 9                      Taqueria EL amigo   No_Alcohol_Served           none
# 10                             palomo tec  No_Alcohol_Served           none
# 11                     puesto de gorditas  No_Alcohol_Served      permitted
# 12                     Gorditas Dona Tota  No_Alcohol_Served  not permitted
# 13                     Taqueria EL amigo   No_Alcohol_Served           none
# 14                             palomo tec  No_Alcohol_Served           none
# 15                          carnitas_mata  No_Alcohol_Served      permitted
# 16         little pizza Emilio Portes Gil  No_Alcohol_Served           none
# 17                                   vips           Full_Bar  not permitted
# 18                              tacos abi  No_Alcohol_Served           none
# 19                          Little Cesarz  No_Alcohol_Served  not permitted
# 20  carnitas mata calle Emilio Portes Gil  No_Alcohol_Served           none
# 21                     Gorditas Dona Tota  No_Alcohol_Served  not permitted
# 22                          Little Cesarz  No_Alcohol_Served  not permitted
# 23                      Cafeteria cenidet  No_Alcohol_Served  not permitted
# 24                       McDonalds Centro  No_Alcohol_Served  not permitted
# 25                 Hamburguesas La perica  No_Alcohol_Served      permitted
# 26               Pollo_Frito_Buenos_Aires  No_Alcohol_Served  not permitted
# 27                          carnitas_mata  No_Alcohol_Served      permitted
# 28                             palomo tec  No_Alcohol_Served           none
# 29                                churchs  No_Alcohol_Served           none
# 30                           tortas hawai  No_Alcohol_Served  not permitted
# 31                          Little Cesarz  No_Alcohol_Served  not permitted
# 32          Carreton de Flautas y Migadas  No_Alcohol_Served      permitted
# 33                          Little Cesarz  No_Alcohol_Served  not permitted
#
#    dress_code   price    area other_services  GlobalRatings  age  distance  \
# 0    informal  medium  closed           none              6   32  0.693407
# 1    informal  medium  closed           none              5   32  0.806876
# 2    informal     low    open           none              6   32  1.036330
# 3    informal  medium  closed           none              5   32  0.729154
# 4    informal  medium  closed        variety              4   31  0.080878
# 5    informal     low  closed           none              3   31  0.170468
# 6    informal     low  closed           none              3   31  0.427612
# 7    informal  medium  closed           none              6   32  0.338330
# 8    informal  medium  closed           none              3   32  0.617608
# 9      casual     low    open           none              5   32  0.358171
# 10   informal     low  closed           none              2   32  0.427612
# 11   informal     low    open           none              1   32  0.172505
# 12   informal  medium  closed           none              4   30  0.336816
# 13     casual     low    open           none              2   30  0.359625
# 14   informal     low  closed           none              3   30  0.426182
# 15   informal  medium  closed           none              6   30  0.365149
# 16   informal     low  closed           none              5   30  0.535381
# 17   informal  medium  closed        variety              3   30  0.080997
# 18   informal     low  closed           none              3   30  0.169029
# 19   informal  medium  closed           none              6   30  0.616119
# 20   informal     low  closed           none              5   30  1.378913
# 21   informal  medium  closed           none              6   30  1.291796
# 22   informal  medium  closed           none              6   30  1.484715
# 23   informal     low  closed           none              6   50  9.547245
# 24   informal     low  closed           none              4   50  4.393866
# 25   informal     low    open           none              5   28  0.641659
# 26   informal     low  closed           none              3   28  0.785439
# 27   informal  medium  closed           none              2   28  0.186382
# 28   informal     low  closed           none              3   30  0.166036
# 29   informal     low  closed           none              6   28  2.227996
# 30   informal  medium  closed           none              6   28  2.031665
# 31   informal  medium  closed           none              5   28  4.166993
# 32   informal     low    open           none              4   28  4.169232
# 33   informal  medium  closed           none              4   32  0.613465
#
#    Review_State
# 0     Excellent
# 1     Excellent
# 2     Excellent
# 3     Excellent
# 4        Medium
# 5        Medium
# 6        Medium
# 7     Excellent
# 8        Medium
# 9     Excellent
# 10          Bad
# 11          Bad
# 12       Medium
# 13          Bad
# 14       Medium
# 15    Excellent
# 16    Excellent
# 17       Medium
# 18       Medium
# 19    Excellent
# 20    Excellent
# 21    Excellent
# 22    Excellent
# 23    Excellent
# 24       Medium
# 25    Excellent
# 26       Medium
# 27          Bad
# 28       Medium
# 29    Excellent
# 30    Excellent
# 31    Excellent
# 32       Medium
# 33       Medium

# %% [markdown]
# #### Create a single column to have the restaurant type

# %%
reviews['Restaurant_type']=reviews[['alcohol','smoking_area','dress_code','price','area']].apply(lambda x: '|'.join(x), axis = 1)

# %% [markdown]
# #### Due to missing multiple values , replace Nan with missing

# %%
reviews.replace(np.nan, 'missing',inplace=True)

# %% [markdown]
# #### Create a single column to have the user type

# %%
reviews['Client_Type']=reviews[['drink_level', 'dress_preference','transport', 'marital_status', 'activity', 'budget']].apply(lambda x: '|'.join(x), axis = 1)

# %% [markdown]
# #### Exportation of the prepared data into a  new csv file

# %%
reviews.to_csv(r'C:\Users\hedi\Desktop\Graduation project\reviewsTest.csv', index = None, header=True)
